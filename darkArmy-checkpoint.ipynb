# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('ggplot')

# %%
df = pd.read_csv("C:/Users/maity/OneDrive/Desktop/darkArmy/bank02.csv")
df.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
num_cols = ["age" , "balance" , "day" , "duration" , "campaign" , "pdays" , "previous"]
cat_cols = [c for c in df.columns if c not in num_cols and c != "deposit"]

# %%
df.hist(figsize=(20,12))
plt.show()

# %%
df.nunique()
# Out:
# age            76
# job            12
# marital         3
# education       4
# default         2
# balance      3805
# housing         2
# loan            2
# contact         3
# day            31
# month          12
# duration     1428
# campaign       36
# pdays         472
# previous       34
# poutcome        4
# deposit         2
# dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.drop("balance",axis=1).corr(),cmap="Blues",annot=True,fmt='.2f')
plt.show()

# %%
sns.scatterplot(df["age"], df["day"],hue=df["balance"])

plt.title("Distribution of balance and income on the basis of age")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Distribution of balance and income on the basis of age')

# %%
plt.figure(figsize=(16,6))
sns.countplot(df["age"])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
